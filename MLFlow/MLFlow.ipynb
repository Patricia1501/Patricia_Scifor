# %%
# Install MLflow 
# %pip install mlflow
# Out:
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.
# Requirement already satisfied: mlflow in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (2.15.1)
# Requirement already satisfied: docker<8,>=4.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from mlflow) (7.1.0)
# Requirement already satisfied: pyarrow<16,>=4.0.0 in /databricks/python3/lib/python3.10/site-packages (from mlflow) (8.0.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from mlflow) (3.1.4)
# Requirement already satisfied: scipy<2 in /databricks/python3/lib/python3.10/site-packages (from mlflow) (1.9.1)
# Requirement already satisfied: Flask<4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from mlflow) (3.0.3)
# Requirement already satisfied: gunicorn<23 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from mlflow) (22.0.0)
# Requirement already satisfied: graphene<4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from mlflow) (3.3)
# Requirement already satisfied: markdown<4,>=3.3 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from mlflow) (3.7)
# Requirement already satisfied: scikit-learn<2 in /databricks/python3/lib/python3.10/site-packages (from mlflow) (1.1.1)
# Requirement already satisfied: alembic!=1.10.0,<2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from mlflow) (1.13.2)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from mlflow) (2.0.32)
# Requirement already satisfied: pandas<3 in /databricks/python3/lib/python3.10/site-packages (from mlflow) (1.4.4)
# Requirement already satisfied: querystring-parser<2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from mlflow) (1.2.4)
# Requirement already satisfied: matplotlib<4 in /databricks/python3/lib/python3.10/site-packages (from mlflow) (3.5.2)
# Requirement already satisfied: mlflow-skinny==2.15.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from mlflow) (2.15.1)
# Requirement already satisfied: numpy<2 in /databricks/python3/lib/python3.10/site-packages (from mlflow) (1.21.5)
# Requirement already satisfied: importlib-metadata!=4.7.0,<8,>=3.7.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from mlflow-skinny==2.15.1->mlflow) (7.2.1)
# Requirement already satisfied: cloudpickle<4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from mlflow-skinny==2.15.1->mlflow) (3.0.0)
# Requirement already satisfied: pyyaml<7,>=5.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from mlflow-skinny==2.15.1->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /databricks/python3/lib/python3.10/site-packages (from mlflow-skinny==2.15.1->mlflow) (2.28.1)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from mlflow-skinny==2.15.1->mlflow) (1.26.0)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from mlflow-skinny==2.15.1->mlflow) (5.4.0)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from mlflow-skinny==2.15.1->mlflow) (3.1.43)
# Requirement already satisfied: entrypoints<1 in /databricks/python3/lib/python3.10/site-packages (from mlflow-skinny==2.15.1->mlflow) (0.4)
# Requirement already satisfied: pytz<2025 in /databricks/python3/lib/python3.10/site-packages (from mlflow-skinny==2.15.1->mlflow) (2022.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from mlflow-skinny==2.15.1->mlflow) (1.26.0)
# Requirement already satisfied: protobuf<6,>=3.12.0 in /databricks/python3/lib/python3.10/site-packages (from mlflow-skinny==2.15.1->mlflow) (3.19.4)
# Requirement already satisfied: packaging<25 in /databricks/python3/lib/python3.10/site-packages (from mlflow-skinny==2.15.1->mlflow) (21.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from mlflow-skinny==2.15.1->mlflow) (0.5.1)
# Requirement already satisfied: databricks-sdk<1,>=0.20.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from mlflow-skinny==2.15.1->mlflow) (0.30.0)
# Requirement already satisfied: click<9,>=7.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from mlflow-skinny==2.15.1->mlflow) (8.1.7)
# Requirement already satisfied: typing-extensions>=4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow) (4.12.2)
# Requirement already satisfied: Mako in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from alembic!=1.10.0,<2->mlflow) (1.3.5)
# Requirement already satisfied: urllib3>=1.26.0 in /databricks/python3/lib/python3.10/site-packages (from docker<8,>=4.0.0->mlflow) (1.26.11)
# Requirement already satisfied: itsdangerous>=2.1.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.6.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from Flask<4->mlflow) (1.8.2)
# Requirement already satisfied: Werkzeug>=3.0.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from Flask<4->mlflow) (3.0.3)
# Requirement already satisfied: aniso8601<10,>=8 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from graphene<4->mlflow) (9.0.1)
# Requirement already satisfied: graphql-relay<3.3,>=3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from graphene<4->mlflow) (3.2.0)
# Requirement already satisfied: graphql-core<3.3,>=3.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from graphene<4->mlflow) (3.2.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from Jinja2<4,>=2.11->mlflow) (2.1.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /databricks/python3/lib/python3.10/site-packages (from matplotlib<4->mlflow) (1.4.2)
# Requirement already satisfied: pillow>=6.2.0 in /databricks/python3/lib/python3.10/site-packages (from matplotlib<4->mlflow) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /databricks/python3/lib/python3.10/site-packages (from matplotlib<4->mlflow) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /databricks/python3/lib/python3.10/site-packages (from matplotlib<4->mlflow) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /databricks/python3/lib/python3.10/site-packages (from matplotlib<4->mlflow) (4.25.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /databricks/python3/lib/python3.10/site-packages (from matplotlib<4->mlflow) (3.0.9)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from querystring-parser<2->mlflow) (1.16.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /databricks/python3/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (2.2.0)
# Requirement already satisfied: joblib>=1.0.0 in /databricks/python3/lib/python3.10/site-packages (from scikit-learn<2->mlflow) (1.2.0)
# Requirement already satisfied: greenlet!=0.4.17 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.0.3)
# Requirement already satisfied: google-auth~=2.0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.15.1->mlflow) (2.33.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.15.1->mlflow) (4.0.11)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata!=4.7.0,<8,>=3.7.0->mlflow-skinny==2.15.1->mlflow) (1.0.0)
# Requirement already satisfied: deprecated>=1.2.6 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.15.1->mlflow) (1.2.14)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.47b0 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.15.1->mlflow) (0.47b0)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.15.1->mlflow) (2022.9.14)
# Requirement already satisfied: charset-normalizer<3,>=2 in /databricks/python3/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.15.1->mlflow) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.10/site-packages (from requests<3,>=2.17.3->mlflow-skinny==2.15.1->mlflow) (3.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.15.1->mlflow) (1.16.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.15.1->mlflow) (5.0.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.15.1->mlflow) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.15.1->mlflow) (0.4.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-44b8f6d4-a2b8-4e02-a342-66dd9e68903f/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.15.1->mlflow) (0.6.0)
# Note: you may need to restart the kernel using dbutils.library.restartPython() to use updated packages.

# %%
# Restart Python kernel to use updated packages
dbutils.library.restartPython()

# %%
import mlflow
import mlflow.sklearn
import pandas as pd
import matplotlib.pyplot as plt

from numpy import savetxt
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes

from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
# %pip list
# Out:
# Package                            Version
# ---------------------------------- -------------
# alembic                            1.13.2
# aniso8601                          9.0.1
# appdirs                            1.4.4
# argon2-cffi                        21.3.0
# argon2-cffi-bindings               21.2.0
# asttokens                          2.2.1
# attrs                              21.4.0
# backcall                           0.2.0
# beautifulsoup4                     4.11.1
# black                              22.6.0
# bleach                             4.1.0
# blinker                            1.8.2
# boto3                              1.24.28
# botocore                           1.27.28
# cachetools                         5.4.0
# certifi                            2022.9.14
# cffi                               1.15.1
# chardet                            4.0.0
# charset-normalizer                 2.0.4
# click                              8.1.7
# cloudpickle                        3.0.0
# cryptography                       37.0.1
# cycler                             0.11.0
# Cython                             0.29.32
# databricks-sdk                     0.30.0
# dbus-python                        1.2.18
# debugpy                            1.6.0
# decorator                          5.1.1
# defusedxml                         0.7.1
# Deprecated                         1.2.14
# distlib                            0.3.7
# distro                             1.7.0
# distro-info                        1.1+ubuntu0.2
# docker                             7.1.0
# docstring-to-markdown              0.12
# entrypoints                        0.4
# executing                          1.2.0
# facets-overview                    1.0.3
# fastjsonschema                     2.18.0
# filelock                           3.12.2
# Flask                              3.0.3
# fonttools                          4.25.0
# gitdb                              4.0.11
# GitPython                          3.1.43
# google-auth                        2.33.0
# googleapis-common-protos           1.56.4
# graphene                           3.3
# graphql-core                       3.2.3
# graphql-relay                      3.2.0
# greenlet                           3.0.3
# grpcio                             1.48.1
# grpcio-status                      1.48.1
# gunicorn                           22.0.0
# httplib2                           0.20.2
# idna                               3.3
# importlib_metadata                 7.2.1
# ipykernel                          6.17.1
# ipython                            8.10.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.7.2
# itsdangerous                       2.2.0
# jedi                               0.18.1
# jeepney                            0.7.1
# Jinja2                             3.1.4
# jmespath                           0.10.0
# joblib                             1.2.0
# jsonschema                         4.16.0
# jupyter-client                     7.3.4
# jupyter_core                       4.11.2
# jupyterlab-pygments                0.1.2
# jupyterlab-widgets                 1.0.0
# keyring                            23.5.0
# kiwisolver                         1.4.2
# launchpadlib                       1.10.16
# lazr.restfulclient                 0.14.4
# lazr.uri                           1.0.6
# Mako                               1.3.5
# Markdown                           3.7
# MarkupSafe                         2.1.5
# matplotlib                         3.5.2
# matplotlib-inline                  0.1.6
# mccabe                             0.7.0
# mistune                            0.8.4
# mlflow                             2.15.1
# mlflow-skinny                      2.15.1
# more-itertools                     8.10.0
# mypy-extensions                    0.4.3
# nbclient                           0.5.13
# nbconvert                          6.4.4
# nbformat                           5.5.0
# nest-asyncio                       1.5.5
# nodeenv                            1.8.0
# notebook                           6.4.12
# numpy                              1.21.5
# oauthlib                           3.2.0
# opentelemetry-api                  1.26.0
# opentelemetry-sdk                  1.26.0
# opentelemetry-semantic-conventions 0.47b0
# packaging                          21.3
# pandas                             1.4.4
# pandocfilters                      1.5.0
# parso                              0.8.3
# pathspec                           0.9.0
# patsy                              0.5.2
# pexpect                            4.8.0
# pickleshare                        0.7.5
# Pillow                             9.2.0
# pip                                22.2.2
# platformdirs                       2.5.2
# plotly                             5.9.0
# pluggy                             1.0.0
# prometheus-client                  0.14.1
# prompt-toolkit                     3.0.36
# protobuf                           3.19.4
# psutil                             5.9.0
# psycopg2                           2.9.3
# ptyprocess                         0.7.0
# pure-eval                          0.2.2
# pyarrow                            8.0.0
# pyarrow-hotfix                     0.5
# pyasn1                             0.6.0
# pyasn1_modules                     0.4.0
# pycparser                          2.21
# pydantic                           1.10.6
# pyflakes                           3.0.1
# Pygments                           2.11.2
# PyGObject                          3.42.1
# PyJWT                              2.3.0
# pyodbc                             4.0.32
# pyparsing                          3.0.9
# pyright                            1.1.294
# pyrsistent                         0.18.0
# python-apt                         2.4.0+ubuntu3
# python-dateutil                    2.8.2
# python-lsp-jsonrpc                 1.0.0
# python-lsp-server                  1.7.1
# pytoolconfig                       1.2.2
# pytz                               2022.1
# PyYAML                             6.0.2
# pyzmq                              23.2.0
# querystring-parser                 1.2.4
# requests                           2.28.1
# rope                               1.7.0
# rsa                                4.9
# s3transfer                         0.6.0
# scikit-learn                       1.1.1
# scipy                              1.9.1
# seaborn                            0.11.2
# SecretStorage                      3.3.1
# Send2Trash                         1.8.0
# setuptools                         63.4.1
# six                                1.16.0
# smmap                              5.0.1
# soupsieve                          2.3.1
# SQLAlchemy                         2.0.32
# sqlparse                           0.5.1
# ssh-import-id                      5.11
# stack-data                         0.6.2
# statsmodels                        0.13.2
# tenacity                           8.1.0
# terminado                          0.13.1
# testpath                           0.6.0
# threadpoolctl                      2.2.0
# tokenize-rt                        4.2.1
# tomli                              2.0.1
# tornado                            6.1
# traitlets                          5.1.1
# typing_extensions                  4.12.2
# ujson                              5.4.0
# unattended-upgrades                0.1
# urllib3                            1.26.11
# virtualenv                         20.16.3
# wadllib                            1.3.6
# wcwidth                            0.2.5
# webencodings                       0.5.1
# Werkzeug                           3.0.3
# whatthepatch                       1.0.2
# wheel                              0.37.1
# widgetsnbextension                 3.6.1
# wrapt                              1.16.0
# yapf                               0.31.0
# zipp                               1.0.0

# %%
db=load_diabetes()
X=db.data
y=db.target
X_train,X_test,y_train,y_test=train_test_split(X,y)

# %%
X.shape,y.shape
# Out:
# ((442, 10), (442,))

# %%
X
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
#         60., 174., 259., 178., 128.,  96., 126., 288.,  88., 292.,  71.,
#        197., 186.,  25.,  84.,  96., 195.,  53., 217., 172., 131., 214.,
#         59.,  70., 220., 268., 152.,  47.,  74., 295., 101., 151., 127.,
#        237., 225.,  81., 151., 107.,  64., 138., 185., 265., 101., 137.,
#        143., 141.,  79., 292., 178.,  91., 116.,  86., 122.,  72., 129.,
#        142.,  90., 158.,  39., 196., 222., 277.,  99., 196., 202., 155.,
#         77., 191.,  70.,  73.,  49.,  65., 263., 248., 296., 214., 185.,
#         78.,  93., 252., 150.,  77., 208.,  77., 108., 160.,  53., 220.,
#        154., 259.,  90., 246., 124.,  67.,  72., 257., 262., 275., 177.,
#         71.,  47., 187., 125.,  78.,  51., 258., 215., 303., 243.,  91.,
#        150., 310., 153., 346.,  63.,  89.,  50.,  39., 103., 308., 116.,
#        145.,  74.,  45., 115., 264.,  87., 202., 127., 182., 241.,  66.,
#         94., 283.,  64., 102., 200., 265.,  94., 230., 181., 156., 233.,
#         60., 219.,  80.,  68., 332., 248.,  84., 200.,  55.,  85.,  89.,
#         31., 129.,  83., 275.,  65., 198., 236., 253., 124.,  44., 172.,
#        114., 142., 109., 180., 144., 163., 147.,  97., 220., 190., 109.,
#        191., 122., 230., 242., 248., 249., 192., 131., 237.,  78., 135.,
#        244., 199., 270., 164.,  72.,  96., 306.,  91., 214.,  95., 216.,
#        263., 178., 113., 200., 139., 139.,  88., 148.,  88., 243.,  71.,
#         77., 109., 272.,  60.,  54., 221.,  90., 311., 281., 182., 321.,
#         58., 262., 206., 233., 242., 123., 167.,  63., 197.,  71., 168.,
#        140., 217., 121., 235., 245.,  40.,  52., 104., 132.,  88.,  69.,
#        219.,  72., 201., 110.,  51., 277.,  63., 118.,  69., 273., 258.,
#         43., 198., 242., 232., 175.,  93., 168., 275., 293., 281.,  72.,
#        140., 189., 181., 209., 136., 261., 113., 131., 174., 257.,  55.,
#         84.,  42., 146., 212., 233.,  91., 111., 152., 120.,  67., 310.,
#         94., 183.,  66., 173.,  72.,  49.,  64.,  48., 178., 104., 132.,
#        220.,  57.])

# %%
mlflow.sklearn.autolog()

# %%
with mlflow.start_run():
  n_estimators=100
  max_depth=6
  max_features=3

rf=RandomForestRegressor(n_estimators=n_estimators,max_depth=max_depth,max_features=max_features)
rf.fit(X_train,y_train)
predictions=rf.predict(X_test)
# Out:
# 2024/08/16 18:26:06 INFO mlflow.tracking._tracking_service.client: 🏃 View run merciful-squid-894 at: https://community.cloud.databricks.com/ml/experiments/1444470096900702/runs/b8e607d3cca14163ab135499766ed067.
# 2024/08/16 18:26:06 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://community.cloud.databricks.com/ml/experiments/1444470096900702.
# 2024/08/16 18:26:06 INFO mlflow.utils.autologging_utils: Created MLflow autologging run with ID '94540a0631ff4f00932203ce911c9ac7', which will track hyperparameters, performance metrics, model artifacts, and lineage information for the current sklearn workflow
# 2024/08/16 18:26:12 WARNING mlflow.utils.autologging_utils: MLflow autologging encountered a warning: "/databricks/python/lib/python3.10/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils."
# 2024/08/16 18:26:13 INFO mlflow.tracking._tracking_service.client: 🏃 View run glamorous-seal-84 at: https://community.cloud.databricks.com/ml/experiments/1444470096900702/runs/94540a0631ff4f00932203ce911c9ac7.
# 2024/08/16 18:26:13 INFO mlflow.tracking._tracking_service.client: 🧪 View experiment at: https://community.cloud.databricks.com/ml/experiments/1444470096900702.
